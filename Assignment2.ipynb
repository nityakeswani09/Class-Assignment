# %% [markdown]
# Q.1 Write a python code to display:
# Value, Type, Memory Address for a Variable using proper built in function

# %%
variable_name = "Krishna"
print(variable_name)
print(type(variable_name))
print(id(variable_name))
# Out:
# Krishna
# <class 'str'>
# 1588155227936

# %% [markdown]
# OUTPUT:
# Krishna
# <class 'str'>
# 1588155227936

# %% [raw]
# 2. What is the difference between: a = 10 b = 10 and a = [10] b = [10] Explain using id().

# %%
a = 10
b = 10
print(a)
print(b)
print("a = ", id(a))
print("b = ", id(b))
# Out:
# 10
# 10
# a =  140708266846936
# b =  140708266846936

# %% [raw]
# Output:   10
# 10
# a =  140708266846936
# b =  140708266846936

# %%
a = [10]
b = [10]
print(a)
print(b)
print(type(a))
print(type(b))
print("a = ", id(a))
print("b = ", id(b))
# Out:
# [10]
# [10]
# <class 'list'>
# <class 'list'>
# a =  1588209537536
# b =  1588209541056

# %% [raw]
# Output: [10]
# [10]
# <class 'list'>
# <class 'list'>
# a =  1588209537536
# b =  1588209541056

# %% [raw]
# 3. What does the id() function return? Is the value returned by id() same for two variables holding the same value?
# Ans. Yes id() return same memory address for same value but for same data type!

# %% [raw]
# 4. What is the purpose of getsizeof()? Why is memory size different for different data types?
# Ans. The getsizeof() function returns the memory size (in bytes) occupied by an object.
#      Different data types store different kinds and amounts of information thats why the size is different internally.

# %% [raw]
# 5. Predict the Output a = 10 b = 10 print(id(a) == id(b)) Explain why this happens.
# Ans. It will return True as in Heap Reference point of variable is pointed to same Value

# %%
a = 10 
b = 10 
print(id(a) == id(b))

#Output : True
# Out:
# True

# %% [raw]
# 6. Write a program that accepts two numbers from user and prints their:  Addition, Subtraction, Multiplication, Division

# %%
print("Enter 1st Number : ")
No1 = int(input())
print("Enter 2nd Number : ")
No2 = int(input())

print("Addition is : ", No1 + No2)
print("Substraction is : ", No1 - No2)
print("Multiplication is : ", No1 * No2)
print("Division is : ", No1 / No2)
# Out:
# Enter 1st Number :
#  15
# Enter 2nd Number :
#  6
# Addition is :  21
# Substraction is :  9
# Multiplication is :  90
# Division is :  2.5

# %% [raw]
# Output: Enter 1st Number :
#  15
# Enter 2nd Number :
#  6
# Addition is :  21
# Substraction is :  9
# Multiplication is :  90
# Division is :  2.5

# %% [raw]
# 7. Why does the input() function always return a string? How can you convert it to another data type?
# Ans: Because of its syntax,it reads data entered by the user from the keyboard as text
# We can convert it to other data type by Type Casting... Initally declaring input as int, float etc
# no1 = int(input())

# %% [raw]
# 8. Predict the output: x = input("Enter number: ") print(type(x)) Explain the reason.
# <class 'str' > It will display str/string

# %% [raw]
# 9. Write a program to take user’s name and age and display: Hello <name>, you will turn <age+1> next year.

# %%
print("Enter Your Name: ")
name = input()
print("Enter Your Age: ")
age = int(input())
print("Hello ", name, "You will turn", age + 1, "next year!")
# Out:
# Enter Your Name:
#  Mukesh
# Enter Your Age:
#  26
# Hello  Mukesh You will turn 27 next year!

# %% [raw]
# 10.What will be the output: print("10" + "20") print(10 + 20) Explain the difference.
# Ans: print("10" + "20") -> Output will be 1020 as it is written in double qoutes("") so it is string and it will concatinate
#  print(10 + 20) -> Output will be 30 as it will read as an opretor (+)
