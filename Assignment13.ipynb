# %% [markdown]
# 1. Write a program which accepts length and width of rectange and prints area.

# %%
length = float(input("Enter Length : "))
width = float(input("Enter width"))

area = length * width

print("Area of rectangle is : ", area)
# Out:
# Area of rectangle is :  26.0

# %% [markdown]
# 2. Write a program which accepts radius of circle and print area of circle

# %%
radius = float(input("Enter raduis of circle : "))
pi = 3.14
area = pi * radius * radius

print("Area of Circle is : ", area)
# Out:
# Area of Circle is :  78.5

# %% [markdown]
# 3. Write a program which accepts one number and checks whether it is perfect number or not.
# Input: 6
# Output: Perfect Number

# %%
number = int(input("Enter number to check whether it is perfect no or not : "))
total = 0
for i in range(1, number):
    if number % i == 0:
        total = total + i

if total == number:
    print(number, "is a perfect number.")
else :
    print(number, "is not perfect number.")

#perfect numbers: 6, 28, 496
# Out:
# 6 is a perfect number.

# %% [markdown]
# 4. Write a program which accepts one number and print binary equivalent

# %%
num = int(input("Enter a number: "))            #23

print("Binary Equivalent =", bin(num)[2:])
# Out:
# Binary Equivalent = 10111

# %% [markdown]
# 5. Write a program which accepts marks and display grade. Condition Example: >= 75 --> distinction,
#                    >= 60 --> first class,
#                    >= 50 --> second class,
#                    <  50 --> fail

# %%
marks = int(input("Enter marks: "))

if marks < 0 or marks > 100:
    print("Invalid Marks")

elif marks >= 75:
    print("Distinction")

elif marks >= 60:
    print("First Class")

elif marks >= 50:
    print("Second Class")

else:
    print("Fail")
# Out:
# Distinction
